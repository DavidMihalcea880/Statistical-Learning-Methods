# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('data/train_selected.csv')
train_data.columns = ['ID', 'Cycle', 'S1','S2','S3','S4','ttf', 'label bnc']
xtrain = train_data.drop([ 'ID', 'label bnc'], axis=1).values
training = pd.DataFrame(xtrain)

# %%
kn = sns.pairplot(training, diag_kind='kde')
